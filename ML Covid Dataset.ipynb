# %%
import numpy as np
import pandas as pd

# %%
url = "/content/covid_worldwide.csv"
data = pd.read_csv(url)
data

# %%
data.describe()

# %%
data.info()

# %%
data.isnull().sum()

# %%
data.isnull().sum()

# %%
data['Total Deaths'] = data["Total Deaths"].fillna(data['Total Deaths'].mode()[0])
data['Total Recovered'] = data["Total Recovered"].fillna(data['Total Recovered'].mode()[0])
data['Active Cases'] = data["Active Cases"].fillna(data['Active Cases'].mode()[0])
data['Total Test'] = data["Total Test"].fillna(data['Total Test'].mode()[0])
data['Population'] = data["Population"].fillna(data['Population'].mode()[0])
